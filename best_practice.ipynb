# %% [markdown]
# ## ImDataSynth
# ImDataSynth is a tool for generating realistic synthetic data including ground truth (GT) with manufacturing context. The start screen is shown below.
# <div align="middle">
# <img src="files/best_practice_files/imdatasynth_startscreen.png" width=80% />
# </div>

# %% [markdown]
# ### 1. Setting up a new experiment
# #### 1.1 Preparation
# To create a new experiment, a data set has to be added first. Enter the name of the data set in the upper text field and confirm it with the 'Add Dataset' button.
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/datansatz_hinzufügen.mov">
# </video>
# </div>

# %% [markdown]
# After adding at least one data set, the options are unlocked. You can navigate through all configuration settings using the tabs at the top (red box). All parameters of the 'General' and 'Model' tabs apply globally to the entire experiment. The configuration for the 'Material', 'Background', 'Cameraviews' and 'Lightning' tabs are selected individually for each data set.
# <div align="middle">
# <img src="files/best_practice_files/uebersicht.jpg" width=80% />
# </div>

# %% [markdown]
# #### 1.2 General configuration
# Basic properties for generating the data and GT are defined within the 'General' tab. The input fields are explained below.
#
# <table style="undefined;table-layout: fixed; width: 513px">
# <colgroup>
# <col style="width: 163px">
# <col style="width: 350px">
# </colgroup>
# <thead>
#   <tr>
#     <td>Source:</td>
#     <td>Origin of the CAD file (e.g. DMU-net)</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Cam-Resolution:</td>
#     <td>Resolution of the camera </td>
#   </tr>
#   <tr>
#     <td>Color Depth:</td>
#     <td>Color depth of the generated images (e.g. 8)</td>
#   </tr>
#   <tr>
#     <td>File Format:</td>
#     <td>File format of the images (e.g. PNG)</td>
#   </tr>
#   <tr>
#     <td>Categories:</td>
#     <td>GT labels of the generated data:<l><li>Cat 1: 'Blender' by default</li><li>Cat 2: Label of the CAD file</li><li>Cat 3: Currently not used)</li><l></td>
#   </tr>
#   <tr>
#     <td>Attributes:</td>
#     <td>Type of rendered GT (visualization see image below). At least one option has to be selected.</td>
#   </tr>
#   <tr>
#     <td>Variant Num:</td>
#     <td>'base' by default</td>
#   </tr>
#   <tr>
#     <td>Create Depth Normal:</td>
#     <td>Render depth and normal images</td>
#   </tr>
#   <tr>
#     <td>Device:</td>
#     <td>Hardware used for rendering:<l><li>No GPU available = 'CPU | None'</li><li>Windows + Nvidia GPU = 'GPU | CUDA'</li><li>Apple = 'CPU | Metal'</li></l></td>
#   </tr>
# </tbody>
# </table>
# <br>
#
# <div align="middle">
# <img src="files/best_practice_files/shader_variants.png" width=80% />
# </div>
#
# Confirm the settings with the 'Apply' button. The 'General' field in the status bar below will turn green.
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/apply_general.mov">
# </video>
# </div>

# %% [markdown]
# #### 1.3 Model configuration
#
# All relevant configurations of the CAD model are defined in this tab. The perferences are specified below.
# <table style="undefined;table-layout: fixed; width: 628px">
# <colgroup>
# <col style="width: 121px">
# <col style="width: 507px">
# </colgroup>
# <thead>
#   <tr>
#     <td>Choose Model:</td>
#     <td>File explorer to navigate to the CAD file. The model has to be in .obj or .stl format!</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Object name:</td>
#     <td>Name of the CAD file</td>
#   </tr>
#   <tr>
#     <td>Label-ID:</td>
#     <td>Unique identifier (e.g. from the DMU-net data set)</td>
#   </tr>
#   <tr>
#     <td>Use base plate:</td>
#     <td>Adds a base plate under the model.</td>
#   </tr>
# </tbody>
# </table>
#
# Hit the 'Apply' button to load the CAD model with the defined configuration into Blender.
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/apply_model.mov">
# </video>
# </div>

# %% [markdown]
# #### 1.4 Material configuration
#
# Here you can select the material for the CAD file and the base plate. The chosen materials are imported from a Blender file (.blend). It is recommended to create a dedicated Blender file as a database for all relevant materials that will be used. Several tutorials for creating a wide variety of surfaces in Blender can be found on the internet (e.g. Youtube search: "blender metal material").<br>
# Load the database. The created materials within the selected .blend file can now be assigned to the model and the base plate.<br>
# Clicking the 'Apply' button, adds the materials to the objects in Blender.<br>
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/apply_material.mov">
# </video>
# </div>

# %% [markdown]
# #### 1.5 Background configuration
#
# In this tab you can pick the background image for the data set. Navigate to the image file using the 'Select' field and confirm it with 'Apply'.<br>
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/apply_background.mov">
# </video>
# </div>

# %% [markdown]
# #### 1.6 Cameraviews configuration
#
# In the 'Cameraviews' tab, the camera positions of the data set are defined. An existing config file can be chosen via the 'Select' field and finally imported clicking the 'Load' button.<br>
# There are three available methods to create new camera positions: 'Sperical Coordinates', 'Icosphere' and 'Custom'. Those are explained individually in the following paragraphs. Hit the 'Apply' button to confirm the adjustments. If you want to export the settings, click on 'Save as json'.
#
# ##### 1.6.1 Spherical Coordiantes method
#
# This method is used to calculate the camera positions with spherical coordinates. The camera is rotated around the model incrementally. The parameters for the adjustment of the calculation are detailed below.
# <table style="undefined;table-layout: fixed; width: 672px">
# <colgroup>
# <col style="width: 150px">
# <col style="width: 522px">
# </colgroup>
# <thead>
#   <tr>
#     <td>Range</td>
#     <td>Rotation range around the model<br>(e.g. -90 - 90 = full circle, 0 - 90 = upper semi-circle)</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Number of Layers</td>
#     <td>Number of camera layers into which the rotation area is to be divided</td>
#   </tr>
#   <tr>
#     <td>Range of Rotations</td>
#     <td>Number of camera positions on the smallest and the largest rotation layer. The layers in between are interpolated.</td>
#   </tr>
#   <tr>
#     <td>Scale</td>
#     <td>Distance of the camera to the center of the object. If 'Relative to object' is set, a distance is calculated that fully catches the object from any angle.</td>
#   </tr>
#   <tr>
#     <td>Z-Offset</td>
#     <td>Additional rotation of all camera positions around the z-axis.</td>
#   </tr>
# </tbody>
# </table><br>
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/cameraview_sph.mov">
# </video>
# </div>

# %% [markdown]
# ##### 1.6.2 Icosphere method
#
# With this method, the camera positions are calculated using an icosphere that is created around the model. The edges of the icosphere are used as camera positions. The available settings are detailled below.
#
# <table style="undefined;table-layout: fixed; width: 672px">
# <colgroup>
# <col style="width: 150px">
# <col style="width: 522px">
# </colgroup>
# <thead>
#   <tr>
#     <td>Scale</td>
#     <td>Size of the icosphere from the center of the model</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Subdivisions</td>
#     <td>Level of detail of the icosphere</td>
#   </tr>
#   <tr>
#     <td>Z-Rotation</td>
#     <td>Rotation of the entire icosphere around the z-axis in degrees</td>
#   </tr>
#   <tr>
#     <td>Camera positioning</td>
#     <td>Area relevant for the camera positions (upper or lower semi-circle, resp. full circle)</td>
#   </tr>
# </tbody>
# </table><br>
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/cameraview_ico.mov">
# </video>
# </div>

# %% [markdown]
# ##### 1.6.3 Custom method
# The 'Custom' method allows you to set the camera positions manually. The x-, y- and z-values are typed into the corresponding fields and the coordinate is appended to the list with the 'Add' button. The arrows can be used to scroll through all entries that have been added so far. The currently selected coordinate can be deleted by using the Delete button. Once you are done, click on 'Apply'.<br>
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/cameraview_custom.mov">
# </video>
# </div>

# %% [markdown]
# #### 1.7 Lighting configuration
# In the 'Lightning' tab, existing lightning setups can be imported via the 'Select' button. New setups have to be created within Blender and can then be applied to the current data set by hitting the 'Update' button. Currently only Area lights are supported. The following video shows step by step how to create a new light setup.
#
# Essential shortcut keys:
#
# <table style="undefined;table-layout: fixed; width: 672px">
# <colgroup>
# <col style="width: 150px">
# <col style="width: 522px">
# </colgroup>
# <thead>
#   <tr>
#     <td>Shift + A</td>
#     <td>Opens the 'Add' menu</td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>G + {X, Y, Z}</td>
#     <td>Move along the {X, Y, Z}-axis</td>
#   </tr>
#   <tr>
#     <td>R + {X, Y, Z}</td>
#     <td>Rotate around the {X, Y, Z}-axis</td>
#   </tr>
# </tbody>
# </table><br>
#
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/apply_lighting.mov">
# </video>
# </div>

# %% [markdown]
# #### 1.8 Name and location of the experiment
# The 'Select' field below the 'Dataset status' can be used to specify the location and the name of the experiment. After confirming, the 'Experiment Directory' turns green. As soon as all 'Dataset status' fields are marked green, the 'Save Experiment' and 'Create Experiment' buttons are enabled.
#
# The 'Save Experiment' button saves the experiment in the specified directory. It can then be rendered on another system (e.g. Elwetritsch).<br>The 'Create Experiment' button also saves the experiment and renders it directly afterwards.<br>
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/exp_dir.mov">
# </video>
# </div>

# %% [markdown]
# ### 2. Loading an existing experiment
#
# An existing experiment can be imported using the 'Select' field at the top. Navigate to the experiment folder, confirm the location using the 'Select' button and hit 'Load Experiment'.<br>
#
# <div align="middle">
# <video width="80%" controls>
#       <source src="files/best_practice_files/load_experiment.mov">
# </video>
# </div>
